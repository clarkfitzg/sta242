# %%
from bokeh.plotting import *

# %%
output_notebook()
# Out:
#
#         <style>
#             /* BEGIN /Users/clark/anaconda/lib/python3.4/site-packages/bokeh/server/static/css/bokeh.min.css */
# ...

# %%
import numpy as np

n = 10000
x = np.random.randn(n)
y = 2 * np.random.randn(n)

# %%
p = figure()
p.circle(x, y, line_alpha=0.2, fill_alpha=0.2)
show(p)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#             var modelid = "e9029f7b-51c4-4880-8ee7-d9bfd5fd2d29";
#             var modeltype = "Plot";
#             var elementid = "2575f721-f838-42ad-b68e-746f95d376c9";
#             Bokeh.logger.info("Realizing plot:")
#             Bokeh.logger.info(" - modeltype: Plot");
#             Bokeh.logger.info(" - modelid: e9029f7b-51c4-4880-8ee7-d9bfd5fd2d29");
#             Bokeh.logger.info(" - elementid: 2575f721-f838-42ad-b68e-746f95d376c9");
# ...
